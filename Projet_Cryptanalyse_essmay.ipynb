# %% [markdown]
# # Cryptanalyse
#
# Votre mission, si vous l'acceptez, est de déchiffrer 4 textes de difficulté croissante en vous aidant d'un programme python que vous allez écrire.
#
#
# - Les fichiers ont été cryptés avec des méthodes données en cours.
# - Les fichiers chiffrés contiennent des textes en ASCII. Une fois déchiffrés ils vous donneront des informations.
# - Vous devez vous baser sur les fréquences d'apparition des lettres en français (et des paires de lettres) pour casser les codes. Faire une fonction de calcul pour vous aider.
# - Penser à réutliser le code du td de cryptographie comme base de travail.
# - Le code de votre programme doit être sur github et vous fournirez un lien vers votre projet github avec le code et le résultat du décodage
# en le déposant sur Moodle avant le mercredi 12 mai.
# - Une soutenance sera organisée le 17 mai.

# %%
0%2
# Out:
# 0

# %%
# Texte_1
# kd oqnbgzhm ehbghdq ztqz tm bncd ozq rtarshstshnm zkogzadshptd: bgzptd kdssqd drs qdlokzbdd ozq tmd ztsqd. tshkhrdq kz eqdptdmbd cdr kdssqdr ontq cdbncdq kd ldrrzfd.

# Raisonnement pour la recherche de la clé :
# le fait qu'on voit deux mots identiques (kz) nous montre que la clé est composé d'une lettre 
# la clé de chiffrement est z mais celle du déchiffrement est b car "z" a été utilisé pour décalé vers l'arrière et on veut maintenant décaler vers l'avant pour retrouver le texte initial.

# ensuite pour le codage :
# la fonction decalage() permet de faire les opérations de décalage dans l'alphabet "classique" puis rajoute 97 pour revenir dans l'alphabet' ascii si :                   - 97 <= son code ascii <=122                                                           sinon elle retourne la lettre du message(permet de garder les ponctuations et espaces)

# la fonction dec_texte() permet de décaler chaque lettre du texte en appelant la fonction decalage() qui prend en argument (lettre du texte, cle[i%taille_cle](au cas où len(cle)> 1)) et ajoute chaque lettre "décalé" dans res


import tkinter as tk

def frequence(message_chiffre):
    resultat = []
    for c in message_chiffre :
        if 97 <= ord(c) <=122:
            exist = True
            for i in range(len(resultat)):
                if resultat[i][0]==c:
                    exist = False
                    resultat[i][1]+=round(1/len(message_chiffre)*100, 2)
            if exist:
                resultat.append([c,round(1/len(message_chiffre)*100, 2)])
    return resultat


def rang(lettre):
    return ord(lettre)-97 #retourne le rang de la lettre dans l'alphabet de a à z(0-25)


def decalage(lettre_message, lettre_cle):
    if 97 <= ord(lettre_message) <= 122:
        return chr((rang(lettre_message) + rang(lettre_cle))%26 + 97)
                                                                #pour l'avoir en ascii
    else:                                                        
        return lettre_message                               


def dec_texte(texte, cle):
    taille_cle = len(cle)
    res = ""
    for i in range(len(texte)):
        res += decalage(texte[i], cle[i%taille_cle])
    return res 


def chiffre():
    resultat.delete(0, tk.END)
    text=entree_texte.get()
    cle = entree_cle.get()
    if((len(text)> 0) and (len(cle)>0)):
        res = dec_texte(text, cle)
        resultat.insert(0, res)
    else :
        resultat.insert(0, "Il manque quelque chose")


racine=tk.Tk()
racine.title("Cryptographie")

entree_texte = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_texte.grid(row = 0, column = 0)

entree_cle = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_cle.grid(row = 1, column = 0)

label_texte = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer le message ici.")
label_texte.grid(row = 0, column = 1)

label_cle = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer la clé ici.")
label_cle.grid(row = 1, column = 1)

label_dech = tk.Label(racine, font = ("helvetica", "20"), text = "Déchiffrer ici")
label_dech.grid(row= 3, column=1)

bouton_coder=tk.Button(racine, text="Chiffrer texte",fg="black", width=15, command=chiffre)
bouton_coder.grid(row=2, column=0)

bouton_decoder=tk.Button(racine,text="Déchiffrer texte",fg="black",  width=15,command=chiffre)
bouton_decoder.grid(row=2, column=1)

resultat=tk.Entry(racine,width = 50, font = ("helvetica", "20"))
resultat.grid(row=3,column=0)


racine.mainloop()

#cle = b
#Solution : le prochain fichier aura un code par substitution alphabetique: chaque lettre est remplacee par une autre. utiliser la frequence des lettres pour decoder le message.

# %%
# Texte_2
# gx qosvlnkd wkvlkxo xiu vscx qno yd fsu cx qniix cx unkggx kdvsddyx xu vsdukxdu g'kdckvx. gxi gxuuoxi cy fsu cx qniix qxofxuuxdu cx cxvngxo gxi gxuuoxi cy fxiinmx sokmkdng fscygs 26. ixygxi gxi gxuuoxi cx n n a isdu vlkwwoxxi.

# Raisonnement : 
# j'ai d'abord essayé de déchiffrer à la main : en m'aidant de la fonction frequence() j'ai remarqué que "x" avait le pourcentage le + important, j'en ai déduis que ça pouvait etre la lettre "e" et en remplaçant x par e dans le texte c'était assez cohérant. Puis, j'ai déduis que "g" correspondait à "l"... et ainsi de suite on retrouve la correspondance de chaque lettre du message.
# la clé correspond à "l'alphabet chiffré" où chaque lettre substituée est à la place de sa correspondance dans l'alphabet et si elle n'est pas présente dans le texte elle correspond à 0

# ensuite pour le codage :
# substitution() permet de retourner la substitution de la lettre du message dans "l'alphabet chiffré" si :                                                               -   97 <= code ascii de lettre_message <=122                                           -et 97 <= code ascii de la lettre correspondant à l'indice de cle <=122                sinon elle retourne la lettre du message (permet de garder les ponctuations, espaces)

# sub_texte() permet de substituer chaque lettre du texte en appelant la fonction substitution() et ajoute chaque lettre "substitué" dans res 

import tkinter as tk
 
cle = "z0dn0ml0s0ihgar0p0o0tcfeu"  #alphabet_chiffre 
     #"abcdefghijklmnopqrtuvwxyz"  #alphabet


def rang(lettre):
    return ord(lettre)-97


def substitution(lettre_message, lettre_cle):
    if 97 <= ord(lettre_message) <=122 and 97 <= ord(lettre_cle[rang(lettre_message)]) <=122 :
        # si 97 <= code ascii de lettre_message <=122 
        # et 97 <= code ascii de la lettre correspondant à l'indice de cle <=122
        return lettre_cle[rang(lettre_message)]
        # retourne sa substitution dans "l'alphabet chiffré" 
    else :
        return lettre_message

def sub_texte(texte,cle):
    res = ""
    for i in range(len(texte)):
        res += substitution(texte[i],cle)
    return res


def chiffre():
    resultat.delete(0, tk.END)
    text=entree_texte.get()
    cle = entree_cle.get()
    if len(text)> 0 and len(cle)>0:
        res = sub_texte(text, cle)
        resultat.insert(0, res)
    else :
        resultat.insert(0, "Il manque quelque chose")


racine=tk.Tk()
racine.title("Cryptographie")

entree_texte = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_texte.grid(row = 0, column = 0)

entree_cle = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_cle.grid(row = 1, column = 0)

label_texte = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer le message ici.")
label_texte.grid(row = 0, column = 1)

label_cle = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer la clé ici.")
label_cle.grid(row = 1, column = 1)

label_dech = tk.Label(racine, font = ("helvetica", "20"), text = "Déchiffrer ici")
label_dech.grid(row= 3, column=1)

bouton_coder=tk.Button(racine, text="Chiffrer texte",fg="black", width=15, command=chiffre)
bouton_coder.grid(row=2, column=0)

bouton_decoder=tk.Button(racine,text="Déchiffrer texte",fg="black",  width=15,command=chiffre)
bouton_decoder.grid(row=2, column=1)

resultat=tk.Entry(racine,width = 50, font = ("helvetica", "20"))
resultat.grid(row=3,column=0)


racine.mainloop()

# cle = "z0dn0ml0s0ihgar0p0o0tcfeu0"
# Solution : Le prochain fichier est code par un mot de passe de taille inconnue  et contient  l’indice. Les lettres du mot de passe permettent de décaler les lettres du message original modulo 26. Seules les lettres de a a z sont chiffrees.

# %%
frequence("gx qosvlnkd wkvlkxo xiu vscx qno yd fsu cx qniix cx unkggx kdvsddyx xu vsdukxdu g'kdckvx. gxi gxuuoxi cy fsu cx qniix qxofxuuxdu cx cxvngxo gxi gxuuoxi cy fxiinmx sokmkdng fscygs 26. ixygxi gxi gxuuoxi cx n n a isdu vlkwwoxxi.")
# Out:
# [['g', 6.160000000000002],
#  ['x', 15.839999999999995],
#  ['q', 2.2],
#  ['o', 4.4],
#  ['s', 4.4],
#  ['v', 3.52],
#  ['l', 1.32],
#  ['n', 4.4],
#  ['k', 4.840000000000001],
#  ['d', 4.840000000000001],
#  ['w', 1.32],
#  ['i', 7.480000000000003],
#  ['u', 7.480000000000003],
#  ['c', 4.840000000000001],
#  ['y', 2.64],
#  ['f', 2.2],
#  ['m', 0.88],
#  ['a', 0.44]]

# %%
# Texte_3
# dceuq e n'ehfp cg p'kyhhep uqfw cgiy citudm c gzudiq ni ezhd px c jhptv ep cggsht. kg hdtymdt xdzei gdx rzyq wir mvzxpw, cifcchdb znwd ccyw wy lkcsht, dp isgd uqfw wy ?


# Raisonnement : 
# Comme pour les textes précédants, on essaye de déchiffrer à la main à l'aide des fréquences des lettres du texte mais comme la clé est plus longue on ne peut pas utiliser la correspondance des lettres des mots qu'on devine car le decalage est différent, ce qui fait qu'on ne peut pas déchiffrer : on reconnait d'abord le mot indice grace à la virgule et l'indice du texte 2, ensuite "bravo" qui est le premier mot

# Maintenant on teste plusieurs lettres et on observe si le début du mot "bravo" apparait :
# avec y --> le b apparait 
# avec yp -->  br apparait
# avec ypw --> bra apparait
# avec ypwb --> la solution apparait !

#remarque : au début j'ai essayé de retrouver le mot "indice" mais je n'y arrivais pas


# ici le codage est le meme que pour le texte 1 sauf qu'on ne connait pas la taille de la clé(len(cle)>1)




import tkinter as tk 

def rang(lettre):
    return ord(lettre)-97


def decalage(lettre_message, lettre_cle):
    if 97 <= ord(lettre_message) <= 122:
        return chr((rang(lettre_message) + rang(lettre_cle))%26 + 97)
    else: 
        return lettre_message


def dec_texte(texte, cle):
    taille_cle = len(cle)
    res = ""
    for i in range(len(texte)):
        res += decalage(texte[i], cle[i%taille_cle])
    return res 


def chiffre():
    resultat.delete(0, tk.END)
    text=entree_texte.get()
    cle = entree_cle.get()
    if((len(text)> 0) and (len(cle)>0)):
        res = dec_texte(text, cle)
        resultat.insert(0, res)
    else :
        resultat.insert(0, "Il manque quelque chose")


racine=tk.Tk()
racine.title("Cryptographie")

entree_texte = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_texte.grid(row = 0, column = 0)

entree_cle = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_cle.grid(row = 1, column = 0)

label_texte = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer le message ici.")
label_texte.grid(row = 0, column = 1)

label_cle = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer la clé ici.")
label_cle.grid(row = 1, column = 1)

label_dech = tk.Label(racine, font = ("helvetica", "20"), text = "Déchiffrer ici")
label_dech.grid(row= 3, column=1)

bouton_coder=tk.Button(racine, text="Chiffrer texte",fg="black", width=15, command=chiffre)
bouton_coder.grid(row=2, column=0)

bouton_decoder=tk.Button(racine,text="Déchiffrer texte",fg="black",  width=15,command=chiffre)
bouton_decoder.grid(row=2, column=1)

resultat=tk.Entry(racine,width = 50, font = ("helvetica", "20"))
resultat.grid(row=3,column=0)


racine.mainloop()

# cle = "ypwb"
# Solution : bravo a l'aide de l'indice vous avez reussi a casser ce code et a finir ce devoir. le dernier texte est pour les braves, regardez vous dans un miroir, en etes vous un ?

# %%
frequence("dceuq e n'ehfp cg p'kyhhep uqfw cgiy citudm c gzudiq ni ezhd px c jhptv ep cggsht. kg hdtymdt xdzei gdx rzyq wir mvzxpw, cifcchdb znwd ccyw wy lkcsht, dp isgd uqfw wy ?")
# Out:
# [['d', 7.199999999999998],
#  ['c', 7.799999999999998],
#  ['e', 4.2],
#  ['u', 3.0],
#  ['q', 3.0],
#  ['n', 1.7999999999999998],
#  ['h', 5.3999999999999995],
#  ['f', 2.4],
#  ['p', 4.8],
#  ['g', 4.8],
#  ['k', 1.7999999999999998],
#  ['y', 4.2],
#  ['w', 4.8],
#  ['i', 4.8],
#  ['t', 3.6],
#  ['m', 1.7999999999999998],
#  ['z', 3.6],
#  ['x', 2.4],
#  ['j', 0.6],
#  ['v', 1.2],
#  ['s', 1.7999999999999998],
#  ['r', 1.2],
#  ['b', 0.6],
#  ['l', 0.6]]

# %%
# Texte_4
# jeqeqecvnf suozvb jfk    
# dfjr fmy rvuqsk ve
# itajtd mifwz nnrt
# imtrvp zuh srzmzbqz tepr zn
#tmsnirt imtrvp nec hw
#dzpqj tjf pdecpr zl jr
#ptejnt ekpb iu b
#iiuyu iy ijz surg rjs ttsn
#votp ac hw rzpuen jozw
#rvwdvx jbo nirscyjv fi

#svmkyw ve iaflss yie te
#teffvv'u riznxjzvv jfk
#nelrhtjrk dh sivdvjvve
#yi cvb à jffrds tdp
#rvwdv sebr onvnqsy zvp
#zuhjwiM le wmifo wiezib nec
#triot qmjvr'c onrwz
#memfqg srq wdaietsq vk


# Raisonnement : 
# l'indice du texte 3 me laisse penser que c'est possible que : 
# les caractères sont en miroir et donc que les lettres sont à l'envers,  "teffvv'u" me confirme l'hypothèse car une apostrophe en fin de mot n'est pas possible en français
# qu'il y a peut etre en plus un décalage de 5 lettres (brave)  

import tkinter as tk


racine=tk.Tk()
racine.title("Cryptographie")

entree_texte = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_texte.grid(row = 0, column = 0)

entree_cle = tk.Entry(racine, width = 50, font = ("helvetica", "20"))
entree_cle.grid(row = 1, column = 0)

label_texte = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer le message ici.")
label_texte.grid(row = 0, column = 1)

label_cle = tk.Label(racine,font = ("helvetica", "20"), text = "Entrer la clé ici.")
label_cle.grid(row = 1, column = 1)

label_dech = tk.Label(racine, font = ("helvetica", "20"), text = "Déchiffrer ici")
label_dech.grid(row= 3, column=1)

bouton_coder=tk.Button(racine, text="Chiffrer texte",fg="black", width=15, command=chiffre)
bouton_coder.grid(row=2, column=0)

bouton_decoder=tk.Button(racine,text="Déchiffrer texte",fg="black",  width=15,command=chiffre)
bouton_decoder.grid(row=2, column=1)

resultat=tk.Entry(racine,width = 50, font = ("helvetica", "20"))
resultat.grid(row=3,column=0)


racine.mainloop()

# cle = ""
# Solution :

# r = e
#

# %%
frequence("jeqeqecvnf suozvb jfk muj dfjr fmy rvuqsk ve itajtd mifwz nnrt imtrvp zuh srzmzbqz tepr zn tmsnirt imtrvp nec hw dzpqj tjf pdecpr zl jr ptejnt ekpb iu b iiuyu iy ijz surg rjs ttsn votp ac hw rzpuen jozw rvwdvx jbo nirscyjv fi svmkyw ve iaflss yie te teffvv'u riznxjzvv jfk nelrhtjrk dh sivdvjvve yi cvb à jffrds tdp rvwdv sebr onvnqsy zvp zuhjwiM le wmifo wiezib nec triot qmjvr'c onrwz memfqg srq wdaietsq vk")
# Out:
# [['j', 5.040000000000003],
#  ['e', 5.280000000000003],
#  ['q', 2.4000000000000004],
#  ['c', 1.92],
#  ['v', 6.480000000000004],
#  ['n', 3.8400000000000016],
#  ['f', 3.6000000000000014],
#  ['s', 4.080000000000002],
#  ['u', 2.6400000000000006],
#  ['o', 1.92],
#  ['z', 4.320000000000002],
#  ['b', 1.92],
#  ['k', 1.68],
#  ['m', 2.880000000000001],
#  ['d', 2.6400000000000006],
#  ['r', 6.0000000000000036],
#  ['y', 1.92],
#  ['i', 5.520000000000003],
#  ['t', 5.040000000000003],
#  ['a', 0.96],
#  ['w', 2.880000000000001],
#  ['p', 2.880000000000001],
#  ['h', 1.44],
#  ['l', 0.96],
#  ['g', 0.48],
#  ['x', 0.48]]
